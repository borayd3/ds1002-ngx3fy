# %% [markdown]
# <a href="https://colab.research.google.com/github/borayd3/ds1002-ngx3fy/blob/main/class%20practice%209.22.2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# import the mockaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# get the head rows - whatever number i want
mock_data.head(3)
# Out:
#    id first_name   last_name                            email  gender  age
# 0   1     Sumner      Duffit  sduffit0@nationalgeographic.com    Male    2
# 1   2        Mic      Lewzey          mlewzey1@washington.edu    Male   20
# 2   3     Gloria  Crosseland          gcrosseland2@cdbaby.com  Female   69

# %%
mock_data.tail()
# Out:
#        id first_name    last_name                        email  gender  age
# 995   996       Rosy        Nashe      rnashern@cloudflare.com  Female   26
# 996   997     Margie       Doogan     mdooganro@craigslist.org  Female   67
# 997   998  Evangelia  Winterflood  ewinterfloodrp@symantec.com  Female    4
# 998   999       Xena       Garvin           xgarvinrq@army.mil  Female   80
# 999  1000   Philbert       Tipler  ptiplerrr@sciencedirect.com    Male    8

# %%
# find specific observation, grab a specific rom from dataframe
mock_data.loc[9]
# Out:
# id                          10
# first_name               Welby
# last_name               Kitman
# email         wkitman9@bbb.org
# gender                    Male
# age                         61
# Name: 9, dtype: object

# %%
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    45.068000
# std     288.819436    25.789503
# min       1.000000     1.000000
# 25%     250.750000    23.000000
# 50%     500.500000    46.000000
# 75%     750.250000    66.250000
# max    1000.000000    90.000000

# %%
# get the columns from the df
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
# what data types are in the df?
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})

# %%
mock_data.head()
# Out:
#    id    fname         lname                            email      gender  age
# 0   1   Sumner        Duffit  sduffit0@nationalgeographic.com        Male    2
# 1   2      Mic        Lewzey          mlewzey1@washington.edu        Male   20
# 2   3   Gloria    Crosseland          gcrosseland2@cdbaby.com      Female   69
# 3   4  Jillene       Covotto              jcovotto3@blogs.com  Polygender    5
# 4   5   Carola  Fraanchyonok       cfraanchyonok4@t-online.de      Female   57

# %%
# get values of one column
mock_data['fname']
# Out:
# 0         Sumner
# 1            Mic
# 2         Gloria
# 3        Jillene
# 4         Carola
#          ...
# 995         Rosy
# 996       Margie
# 997    Evangelia
# 998         Xena
# 999     Philbert
# Name: fname, Length: 1000, dtype: object

# %%
mock_data.fname
# Out:
# 0         Sumner
# 1            Mic
# 2         Gloria
# 3        Jillene
# 4         Carola
#          ...
# 995         Rosy
# 996       Margie
# 997    Evangelia
# 998         Xena
# 999     Philbert
# Name: fname, Length: 1000, dtype: object

# %%
mock_data[['fname','lname']]
# Out:
#          fname         lname
# 0       Sumner        Duffit
# 1          Mic        Lewzey
# 2       Gloria    Crosseland
# 3      Jillene       Covotto
# 4       Carola  Fraanchyonok
# ..         ...           ...
# 995       Rosy         Nashe
# 996     Margie        Doogan
# 997  Evangelia   Winterflood
# 998       Xena        Garvin
# 999   Philbert        Tipler
#
# [1000 rows x 2 columns]

# %%
pd.value_counts(mock_data['gender']).plot.bar()
# Out:
# <Axes: >

# %%
mock_data.groupby(['gender'])['age'].mean()
# Out:
# gender
# Agender        54.125000
# Bigender       38.714286
# Female         44.621924
# Genderfluid    52.666667
# Genderqueer    45.750000
# Male           44.912281
# Non-binary     52.625000
# Polygender     42.619048
# Name: age, dtype: float64
